# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data

# %%
df = pd.read_csv("C:/Users/User/Desktop/Mine/A_D_S/Assignment_4/ADS-Assignment-4/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.notna().sum()
# Out:
# customerID          7043
# gender              7043
# SeniorCitizen       7043
# Partner             7043
# Dependents          7043
# tenure              7043
# PhoneService        7043
# MultipleLines       7043
# InternetService     7043
# OnlineSecurity      7043
# OnlineBackup        7043
# DeviceProtection    7043
# TechSupport         7043
# StreamingTV         7043
# StreamingMovies     7043
# Contract            7043
# PaperlessBilling    7043
# PaymentMethod       7043
# MonthlyCharges      7043
# TotalCharges        7043
# Churn               7043
# dtype: int64

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# # TotalCharges column should be a float

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df = df.replace(np.nan, 0, regex=True)
print(df)
print(df.dtypes)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ### 1a. Which 2 demographics have proven to be the most popular with the telco brand?
#
# #### Answer: Married and unmarried people

# %% [markdown]
# #account_cols = [
#     "tenure",
#     "Contract",
#     "PaymentMethod",
#     "PaperlessBilling",
#     "MonthlyCharges",
#     "TotalCharges",
# ]

# %%
fig = px.histogram(
    data_frame=df,
    x="tenure",
    color="Partner",
    barmode="group",
    nbins=30,
    title="Popularity by <b>Partner</b> customers",
)
fig.show()
# Out:
# <div>                            <div id="a9a40244-3361-4577-95af-b3c7e963a0ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9a40244-3361-4577-95af-b3c7e963a0ec")) {                    Plotly.newPlot(                        "a9a40244-3361-4577-95af-b3c7e963a0ec",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Partner=Yes<br>tenure=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","nbinsx":30,"offsetgroup":"Yes","orientation":"v","showlegend":true,"x":[1,28,13,58,69,10,12,58,49,47,1,72,71,2,27,72,10,70,17,13,69,25,8,60,63,66,34,47,72,18,47,50,52,64,62,8,45,11,7,49,35,48,46,29,30,66,71,25,1,66,68,72,72,55,37,64,3,10,27,56,7,4,72,25,64,1,72,61,71
# ...

# %%
fig = px.histogram(
    data_frame=df,
    x="tenure",
    color="Churn",
    barmode="group",
    nbins=30,
    title="Popularity by <b>churning</b> and <b>non-churning</b> customers",
)
fig.show()
# Out:
# <div>                            <div id="ba8443fc-4ffa-4214-b3dd-570043048593" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba8443fc-4ffa-4214-b3dd-570043048593")) {                    Plotly.newPlot(                        "ba8443fc-4ffa-4214-b3dd-570043048593",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>tenure=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","nbinsx":30,"offsetgroup":"No","orientation":"v","showlegend":true,"x":[1,34,45,22,10,62,13,16,58,25,69,52,71,21,12,58,49,30,72,71,2,27,1,1,72,46,10,70,17,63,13,49,2,52,69,43,25,60,63,66,34,72,47,60,72,18,3,47,31,50,10,1,52,64,62,3,56,46,8,30,45,11,42,49,9,35,48,46,29,30,1
# ...

# %%
fig = px.histogram(
    data_frame=df,
    x="tenure",
    color="gender",
    barmode="group",
    nbins=30,
    title="Popularity by <b>gender</b> customers",
)
fig.show()
# Out:
# <div>                            <div id="c2687c9e-a33d-4f0a-b7d0-4afcd7dca00c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2687c9e-a33d-4f0a-b7d0-4afcd7dca00c")) {                    Plotly.newPlot(                        "c2687c9e-a33d-4f0a-b7d0-4afcd7dca00c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender=Female<br>tenure=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","nbinsx":30,"offsetgroup":"Female","orientation":"v","showlegend":true,"x":[1,2,8,10,28,69,52,10,21,58,30,17,71,27,72,46,11,70,17,63,13,49,2,69,43,15,25,8,60,63,34,72,47,18,9,3,31,50,52,3,56,46,8,45,1,11,7,42,49,35,48,46,65,12,25,1,66,72,32,52,43,37,64,36,10,4
# ...

# %% [markdown]
# ### 1b.  If the marketing team wanted to increase customer retention, to whom should they target their advertisements to?
# #### Answer : Unmarried Males with a month-to-month type of contract

# %%
fig = px.histogram(
    data_frame=df,
    x="Contract",
    color="Partner",
    title="Contract type distribution for new customers",
)

fig.show()
# Out:
# <div>                            <div id="e48282ea-de23-47b0-b338-0d19a4b73a73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e48282ea-de23-47b0-b338-0d19a4b73a73")) {                    Plotly.newPlot(                        "e48282ea-de23-47b0-b338-0d19a4b73a73",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Partner=Yes<br>Contract=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"x":["Month-to-month","Month-to-month","Month-to-month","One year","Two year","Month-to-month","One year","Two year","Month-to-month","Month-to-month","Month-to-month","Two year","Two year","Month-to-month","On
# ...

# %%
fig = px.histogram(
    data_frame=df,
    x="Contract",
    color="gender",
    title="Contract type distribution for new customers",
)

fig.show()
# Out:
# <div>                            <div id="34b8304a-909d-420d-96fe-b54a1f5fe75b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34b8304a-909d-420d-96fe-b54a1f5fe75b")) {                    Plotly.newPlot(                        "34b8304a-909d-420d-96fe-b54a1f5fe75b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"gender=Female<br>Contract=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"x":["Month-to-month","Month-to-month","Month-to-month","Month-to-month","Month-to-month","Two year","One year","Month-to-month","Month-to-month","Two year","Month-to-month","Month-to-month","Two yea
# ...

# %% [markdown]
# ### 2a. Which 3 services are contributing to a higher monthly charge and resulting to customers
# ### churning? (Use visualizations in explaining your analysis)
#
# #### Answer: FiberOptics, Multiple Lines, No phone service

# %%
fig = px.histogram(
    data_frame=df,
    x="PhoneService",
    y="MonthlyCharges",
    color="Churn",
    title="PhoneService",
)

fig.show()
# Out:
# <div>                            <div id="27a1c307-4a3b-4c56-b7c3-79af0345f1fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27a1c307-4a3b-4c56-b7c3-79af0345f1fb")) {                    Plotly.newPlot(                        "27a1c307-4a3b-4c56-b7c3-79af0345f1fb",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Churn=No<br>PhoneService=%{x}<br>sum of MonthlyCharges=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Ye
# ...

# %%
fig = px.histogram(
    data_frame=df,
    x="MonthlyCharges",
    color="MultipleLines",
    barmode="group",
    facet_row="Churn",
    nbins=20,
    height=800,
    title="Monthly charges distribution for different values of <i>MultpleLines</i>",
)

fig.show()
# Out:
# <div>                            <div id="86d61a24-7a27-45c8-a119-ee04db483501" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86d61a24-7a27-45c8-a119-ee04db483501")) {                    Plotly.newPlot(                        "86d61a24-7a27-45c8-a119-ee04db483501",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"MultipleLines=No phone service<br>Churn=No<br>MonthlyCharges=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No phone service","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No phone service","nbinsx":20,"offsetgroup":"No phone service","orientation":"v","showlegend":true,"x":[29.85,42.3,29.75,42.1,50.55,33.75,45.55,24.3,30.15,54.6,31.05,56.45,30.4,55.45,25.25,58.75,45.25,56.6,50.6,29.6,59.55
# ...

# %%
fig = px.histogram(
    data_frame=df,
    x="InternetService",
    color="Churn",
    title="Internet Service Distribution",
)

fig.show()
# Out:
# <div>                            <div id="dbf41868-1cce-4a31-a026-ad1ae4f58d6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbf41868-1cce-4a31-a026-ad1ae4f58d6f")) {                    Plotly.newPlot(                        "dbf41868-1cce-4a31-a026-ad1ae4f58d6f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>InternetService=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["DSL","DSL","DSL","Fiber optic","DSL","DSL","DSL","No","Fiber optic","Fiber optic","Fiber optic","No","Fiber optic","Fiber optic","No","DSL","DSL","DSL","DSL","Fiber optic","Fiber optic","DSL","No","DSL",
# ...

# %%
fig = px.histogram(
    data_frame=df,
    x="MonthlyCharges",
    color="InternetService",
    barmode="group",
    facet_row="Churn",
    nbins=20,
    height=800,
    title='MonthlyCharges vs <i>internet service</i>'
)

fig.show()
# Out:
# <div>                            <div id="ffec3c0f-952e-4495-b9a6-3b736e67d27f" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffec3c0f-952e-4495-b9a6-3b736e67d27f")) {                    Plotly.newPlot(                        "ffec3c0f-952e-4495-b9a6-3b736e67d27f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"InternetService=DSL<br>Churn=No<br>MonthlyCharges=%{x}<br>count=%{y}<extra></extra>","legendgroup":"DSL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"DSL","nbinsx":20,"offsetgroup":"DSL","orientation":"v","showlegend":true,"x":[29.85,56.95,42.3,29.75,56.15,49.95,59.9,59.6,55.3,90.25,66.15,45.25,49.55,69.2,79.85,76.2,49.25,79.75,64.15,69.5,74.85,42.1,54.4,75.3,79.2,49.05,64.5,55.65,54.65,74.75
# ...

# %% [markdown]
# ### 2b. If the telco was to offer Phone as a standalone service, which type of contract
# ### would encourage customer retention?
#
# #### Answer: Month-to-month

# %%
fig = px.histogram(
    data_frame=df,
    x="tenure",
    color="Contract",
    barmode="group",
    facet_row="PhoneService",
    nbins=20,
    height=800,
    title='PhoneService vs <i>Contract type</i>'
)

fig.show()
# Out:
# <div>                            <div id="4bfda8b3-e6dc-4b7e-8fa7-dcfb42dedcf7" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4bfda8b3-e6dc-4b7e-8fa7-dcfb42dedcf7")) {                    Plotly.newPlot(                        "4bfda8b3-e6dc-4b7e-8fa7-dcfb42dedcf7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Contract=Month-to-month<br>PhoneService=No<br>tenure=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Month-to-month","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Month-to-month","nbinsx":20,"offsetgroup":"Month-to-month","orientation":"v","showlegend":true,"x":[1,10,1,1,11,29,5,25,1,58,1,1,3,1,57,1,29,3,1,14,28,23,21,27,1,33,10,26,60,48,5,13,9,8,10,4,49,52,2,26,32,11,3,6,34,13,60,3,1,13,7,4
# ...

# %% [markdown]
# ### 3a. If the company was to streamline all its services into 3 bouquet packages, what
# ### monthly prices will be appropriate for the following packages to keep customers
# ### from churning:
# ### i. Basic
# ### ii. Plus
# ### iii. Premium
# ##### min        18.250000}Basic
# ##### 25%        35.500000}Basic
# ##### 50%        70.350000}Plus
# ##### 75%        89.850000}Plus
# ##### max       118.750000}Premium

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
fig = px.histogram(
    data_frame=df,
    x="Churn",
    
    color="InternetService",
    facet_row="StreamingTV",
    nbins=20,
    height=800,
    title='Churn vs <i>InternetService</i>'
)

fig.show()
# Out:
# <div>                            <div id="900daed4-16fc-4263-bfa6-6e981eac9f9c" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("900daed4-16fc-4263-bfa6-6e981eac9f9c")) {                    Plotly.newPlot(                        "900daed4-16fc-4263-bfa6-6e981eac9f9c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"InternetService=DSL<br>StreamingTV=No<br>Churn=%{x}<br>count=%{y}<extra></extra>","legendgroup":"DSL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"DSL","nbinsx":20,"offsetgroup":"DSL","orientation":"v","showlegend":true,"x":["No","No","Yes","No","No","No","No","Yes","Yes","No","No","No","Yes","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","Yes",
# ...

# %%
fig=px.box(df, y='MonthlyCharges', x='Churn')
fig.show()
# Out:
# <div>                            <div id="60c90fe3-a18e-4204-b43d-7c7decb95eb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60c90fe3-a18e-4204-b43d-7c7decb95eb8")) {                    Plotly.newPlot(                        "60c90fe3-a18e-4204-b43d-7c7decb95eb8",                        [{"alignmentgroup":"True","hovertemplate":"Churn=%{x}<br>MonthlyCharges=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["No","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","No","No","No","No","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","No","No","Yes","No","Yes","Yes","No","No","No","No","No","No",
# ...

# %% [markdown]
# ### 3b. Should the company strictly go paperless for their monthly billings as a technique
# ### of keeping their customers and why?
#
# ### Answer: Yes, the company should go paperless billing, beacause majority of customers
# ### paying higher monthly charges prefer paperless billing and are retained for longer (tenure)

# %%
fig = px.histogram(
    data_frame=df,
    x="MonthlyCharges",
    color="Churn",
    barmode="group",
    facet_row="PaperlessBilling",
    nbins=20,
    height=800,
    title='PaperlessBilling vs <i>Churn</i>'
)

fig.show()
# Out:
# <div>                            <div id="58978787-7953-4367-a150-c2ec184c312c" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58978787-7953-4367-a150-c2ec184c312c")) {                    Plotly.newPlot(                        "58978787-7953-4367-a150-c2ec184c312c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>PaperlessBilling=Yes<br>MonthlyCharges=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","nbinsx":20,"offsetgroup":"No","orientation":"v","showlegend":true,"x":[29.85,89.1,49.95,105.5,90.05,59.9,55.3,90.25,96.35,95.5,74.8,69.2,79.85,76.2,84.5,79.75,64.15,90.25,69.5,74.85,99.65,108.45,107.5,100.5,89.9,54.4,75.3,78.9,79.85,20.4,11
# ...

# %%
fig = px.histogram(
    data_frame=df,
    x="tenure",
    color="Churn",
    barmode="group",
    facet_row="PaperlessBilling",
    nbins=20,
    height=800,
    title='PaperlessBilling vs <i>tenure</i>'
)

fig.show()
# Out:
# <div>                            <div id="06d1de52-4120-45b6-ba9a-9beee5d1a437" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06d1de52-4120-45b6-ba9a-9beee5d1a437")) {                    Plotly.newPlot(                        "06d1de52-4120-45b6-ba9a-9beee5d1a437",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=No<br>PaperlessBilling=Yes<br>tenure=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","nbinsx":20,"offsetgroup":"No","orientation":"v","showlegend":true,"x":[1,22,13,25,21,58,30,72,71,2,46,70,63,13,49,52,69,43,25,60,63,66,72,47,60,18,3,47,10,52,64,62,3,30,45,42,49,9,35,46,66,65,72,71,72,43,64,27,56,33,72,71,13,43,23,57,72,61,64,65,15
# ...
